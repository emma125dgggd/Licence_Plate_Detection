# %% [markdown]
# ## 1. Make sure you have a GPU
# **IMPORTANT**: Run this command to check if Google Colab gave you a GPU, if not you can change your gmail account on the top right corner of this page and you will get one.

# %%
# !nvidia-smi
# Out:
# Wed Mar 27 21:18:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Install the theos python package

# %%
# !python3.10 -m pip install theos-ai==0.0.36
# Out:
# Collecting theos-ai==0.0.36
#   Downloading theos_ai-0.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 42.3 MB/s eta 0:00:00
# Collecting Pillow==8.3.2 (from theos-ai==0.0.36)
#   Downloading Pillow-8.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 73.8 MB/s eta 0:00:00
# Collecting python-socketio==5.3.0 (from theos-ai==0.0.36)
#   Downloading python_socketio-5.3.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 8.8 MB/s eta 0:00:00
# Collecting psutil==5.8.0 (from theos-ai==0.0.36)
#   Downloading psutil-5.8.0.tar.gz (470 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.9/470.9 kB 54.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting GPUtil==1.4.0 (from theos-ai==0.0.36)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting urllib3==1.26.7 (from theos-ai==0.0.36)
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 22.6 MB/s eta 0:00:00
# Collecting requests==2.25.0 (from theos-ai==0.0.36)
#   Downloading requests-2.25.0-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 9.7 MB/s eta 0:00:00
# Collecting httpx==0.18.0 (from theos-ai==0.0.36)
#   Downloading httpx-0.18.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 13.3 MB/s eta 0:00:00
# Collecting aiofiles==0.6.0 (from theos-ai==0.0.36)
#   Downloading aiofiles-0.6.0-py3-none-any.whl (11 kB)
# Collecting docker==4.3.1 (from theos-ai==0.0.36)
#   Downloading docker-4.3.1-py2.py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.2/145.2 kB 23.4 MB/s eta 0:00:00
# Collecting opencv-python==4.6.0.66 (from theos-ai==0.0.36)
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 12.9 MB/s eta 0:00:00
# Collecting distro==1.5.0 (from theos-ai==0.0.36)
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting matplotlib==3.5.3 (from theos-ai==0.0.36)
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 94.3 MB/s eta 0:00:00
# Collecting colorama==0.4.4 (from theos-ai==0.0.36)
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting yaspin==1.1.0 (from theos-ai==0.0.36)
#   Downloading yaspin-1.1.0-py2.py3-none-any.whl (26 kB)
# Collecting tqdm==4.48.0 (from theos-ai==0.0.36)
#   Downloading tqdm-4.48.0-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 11.3 MB/s eta 0:00:00
# Collecting Flask-SocketIO==5.1.0 (from theos-ai==0.0.36)
#   Downloading Flask_SocketIO-5.1.0-py2.py3-none-any.whl (16 kB)
# Collecting SQLAlchemy==1.3.22 (from theos-ai==0.0.36)
#   Downloading SQLAlchemy-1.3.22.tar.gz (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 81.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting websockets==10.3 (from theos-ai==0.0.36)
#   Downloading websockets-10.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.10/dist-packages (from theos-ai==0.0.36) (6.0.1)
# Collecting py-cpuinfo==8.0.0 (from theos-ai==0.0.36)
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.8/99.8 kB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting imagesize==1.2.0 (from theos-ai==0.0.36)
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting nest-asyncio==1.5.6 (from theos-ai==0.0.36)
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting shutup==0.2.0 (from theos-ai==0.0.36)
#   Downloading shutup-0.2.0-py3-none-any.whl (1.5 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker==4.3.1->theos-ai==0.0.36) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker==4.3.1->theos-ai==0.0.36) (1.7.0)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.10/dist-packages (from Flask-SocketIO==5.1.0->theos-ai==0.0.36) (2.2.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.18.0->theos-ai==0.0.36) (2024.2.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.18.0->theos-ai==0.0.36) (1.3.1)
# Collecting rfc3986[idna2008]<2,>=1.3 (from httpx==0.18.0->theos-ai==0.0.36)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.14.0,>=0.13.0 (from httpx==0.18.0->theos-ai==0.0.36)
#   Downloading httpcore-0.13.7-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (1.4.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (24.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3->theos-ai==0.0.36) (2.8.2)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from python-socketio==5.3.0->theos-ai==0.0.36) (0.23.1)
# Collecting python-engineio>=4.1.0 (from python-socketio==5.3.0->theos-ai==0.0.36)
#   Downloading python_engineio-4.9.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.8 MB/s eta 0:00:00
# Collecting chardet<4,>=3.0.2 (from requests==2.25.0->theos-ai==0.0.36)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 21.6 MB/s eta 0:00:00
# Collecting idna<3,>=2.5 (from requests==2.25.0->theos-ai==0.0.36)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->Flask-SocketIO==5.1.0->theos-ai==0.0.36) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->Flask-SocketIO==5.1.0->theos-ai==0.0.36) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->Flask-SocketIO==5.1.0->theos-ai==0.0.36) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->Flask-SocketIO==5.1.0->theos-ai==0.0.36) (8.1.7)
# Collecting h11<0.13,>=0.11 (from httpcore<0.14.0,>=0.13.0->httpx==0.18.0->theos-ai==0.0.36)
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore<0.14.0,>=0.13.0->httpx==0.18.0->theos-ai==0.0.36) (3.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio==3.*->httpcore<0.14.0,>=0.13.0->httpx==0.18.0->theos-ai==0.0.36) (1.2.0)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.1.0->python-socketio==5.3.0->theos-ai==0.0.36)
#   Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask>=0.9->Flask-SocketIO==5.1.0->theos-ai==0.0.36) (2.1.5)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.1.0->python-socketio==5.3.0->theos-ai==0.0.36)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: GPUtil, psutil, py-cpuinfo, SQLAlchemy
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=befa46c7decb99bfbda19d1c26c2c1c8466ac32c8ae6a68b928da73f8ee3c003
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.8.0-cp310-cp310-linux_x86_64.whl size=282790 sha256=a55ebfbdcf410753dc8829680230c2286c007abfd1794d660f018a344a84302f
#   Stored in directory: /root/.cache/pip/wheels/12/a3/6d/615295409067d58a62a069d30d296d61d3ac132605e3a9555c
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22243 sha256=dde46a3c121f25510abd91874353d84c71a55da4e015d324090f20d7ada646a1
#   Stored in directory: /root/.cache/pip/wheels/9a/51/9c/985fe94d3aae45d04bebca10446ca64ad968a750de452ad474
#   Building wheel for SQLAlchemy (setup.py) ... done
#   Created wheel for SQLAlchemy: filename=SQLAlchemy-1.3.22-cp310-cp310-linux_x86_64.whl size=1246864 sha256=017244ad9a188fe8ed9bb8b65b56b5b269cc087e9ce5c4a04f21b4f1274c241f
#   Stored in directory: /root/.cache/pip/wheels/37/f0/d7/9c7fd336b37c0b5a1d97ddaff84bbd765337353cfc8619f40b
# Successfully built GPUtil psutil py-cpuinfo SQLAlchemy
# Installing collected packages: rfc3986, py-cpuinfo, GPUtil, distro, chardet, aiofiles, yaspin, websockets, urllib3, tqdm, SQLAlchemy, shutup, psutil, Pillow, opencv-python, nest-asyncio, imagesize, idna, h11, colorama, wsproto, requests, matplotlib, simple-websocket, httpcore, docker, python-engineio, httpx, python-socketio, Flask-SocketIO, theos-ai
#   Attempting uninstall: py-cpuinfo
#     Found existing installation: py-cpuinfo 9.0.0
#     Uninstalling py-cpuinfo-9.0.0:
#       Successfully uninstalled py-cpuinfo-9.0.0
#   Attempting uninstall: distro
#     Found existing installation: distro 1.7.0
#     Uninstalling distro-1.7.0:
#       Successfully uninstalled distro-1.7.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.29
#     Uninstalling SQLAlchemy-2.0.29:
#       Successfully uninstalled SQLAlchemy-2.0.29
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.6.0
#     Uninstalling nest-asyncio-1.6.0:
#       Successfully uninstalled nest-asyncio-1.6.0
#   Attempting uninstall: imagesize
#     Found existing installation: imagesize 1.4.1
#     Uninstalling imagesize-1.4.1:
#       Successfully uninstalled imagesize-1.4.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.0.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.3 which is incompatible.
# bigframes 1.0.0 requires requests>=2.27.1, but you have requests 2.25.0 which is incompatible.
# bigframes 1.0.0 requires sqlalchemy<3.0dev,>=1.4, but you have sqlalchemy 1.3.22 which is incompatible.
# fastai 2.7.14 requires pillow>=9.0.0, but you have pillow 8.3.2 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.25.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.22 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.3 which is incompatible.
# torchvision 0.17.1+cu121 requires pillow!=8.3.*,>=5.3.0, but you have pillow 8.3.2 which is incompatible.
# tweepy 4.14.0 requires requests<3,>=2.27.0, but you have requests 2.25.0 which is incompatible.
# yfinance 0.2.37 requires requests>=2.31, but you have requests 2.25.0 which is incompatible.
# Successfully installed Flask-SocketIO-5.1.0 GPUtil-1.4.0 Pillow-8.3.2 SQLAlchemy-1.3.22 aiofiles-0.6.0 chardet-3.0.4 colorama-0.4.4 distro-1.5.0 docker-4.3.1 h11-0.12.0 httpcore-0.13.7 httpx-0.18.0 idna-2.10 imagesize-1.2.0 matplotlib-3.5.3 nest-asyncio-1.5.6 opencv-python-4.6.0.66 psutil-5.8.0 py-cpuinfo-8.0.0 python-engineio-4.9.0 python-socketio-5.3.0 requests-2.25.0 rfc3986-1.5.0 shutup-0.2.0 simple-websocket-1.0.0 theos-ai-0.0.36 tqdm-4.48.0 urllib3-1.26.7 websockets-10.3 wsproto-1.2.0 yaspin-1.1.0

# %% [markdown]
# ## 3. Run the setup to finish installing theos
# After the installation finishes an error message will probably show up, you can safely ignore it and continue with the next step.

# %%
# !theos setup --version v1
# Out:
# [theos] what are you going to train?
#
# 1. YOLO (Object Detection).
# 2. YOLO (Pose Estimation).
# 3. Paddle (OCR).
#
# [*] enter your choice (1, 2 or 3): 1
#
# [theos] setting up object-detection subfield...
#
# Collecting scipy==1.11.1
#   Downloading scipy-1.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 41.6 MB/s eta 0:00:00
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#      ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/750.6 MB 121.9 MB/s eta 0:00:061
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.3 MB/s eta 0:00:00
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 64.8 MB/s eta 0:00:00
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.1/283.1 kB 37.3 MB/s eta 0:00:00
# Collecting pandas==1.3.4
#   Downloading pandas-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 100.2 MB/s eta 0:00:00
# Collecting tensorflow==2.10.0
#   Downloading tensorflow-2.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.0/578.0 MB 2.6 MB/s eta 0:00:00
# Collecting tensorflowjs==4.0.0
#   Downloading tensorflowjs-4.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.7/83.7 kB 12.4 MB/s eta 0:00:00
# Collecting tensorflow-decision-forests==1.0.1
#   Downloading tensorflow_decision_forests-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 91.8 MB/s eta 0:00:00
# Collecting numpy==1.21.6
#   Downloading numpy-1.21.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 93.5 MB/s eta 0:00:00
# Collecting typing-extensions (from torch==1.11.0)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting requests (from torchvision==0.12.0)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 10.4 MB/s eta 0:00:00
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision==0.12.0)
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 84.4 MB/s eta 0:00:00
# Collecting matplotlib>=2.2 (from seaborn==0.11.0)
#   Downloading matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 112.5 MB/s eta 0:00:00
# Collecting python-dateutil>=2.7.3 (from pandas==1.3.4)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 31.6 MB/s eta 0:00:00
# Collecting pytz>=2017.3 (from pandas==1.3.4)
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 45.6 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0 (from tensorflow==2.10.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 21.9 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0 (from tensorflow==2.10.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=2.0 (from tensorflow==2.10.0)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.10.0)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.10.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 9.4 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.10.0)
#   Downloading grpcio-1.62.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 105.8 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow==2.10.0)
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 111.2 MB/s eta 0:00:00
# Collecting keras<2.11,>=2.10.0 (from tensorflow==2.10.0)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.9 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.10.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 138.1 kB/s eta 0:00:00
# Collecting libclang>=13.0.0 (from tensorflow==2.10.0)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 49.9 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.10.0)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 9.5 MB/s eta 0:00:00
# Collecting packaging (from tensorflow==2.10.0)
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 8.2 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.10.0)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.8 MB/s eta 0:00:00
# Collecting setuptools (from tensorflow==2.10.0)
#   Downloading setuptools-69.2.0-py3-none-any.whl (821 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.5/821.5 kB 60.9 MB/s eta 0:00:00
# Collecting six>=1.12.0 (from tensorflow==2.10.0)
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow==2.10.0)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 107.4 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.10.0)
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 104.6 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow==2.10.0)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 48.4 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0 (from tensorflow==2.10.0)
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting wrapt>=1.11.0 (from tensorflow==2.10.0)
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 12.4 MB/s eta 0:00:00
# Collecting flax>=0.5.3 (from tensorflowjs==4.0.0)
#   Downloading flax-0.8.2-py3-none-any.whl (686 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.8/686.8 kB 62.4 MB/s eta 0:00:00
# Collecting importlib_resources>=5.9.0 (from tensorflowjs==4.0.0)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting jax>=0.3.16 (from tensorflowjs==4.0.0)
#   Downloading jax-0.4.25-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 97.5 MB/s eta 0:00:00
# Collecting tensorflow-hub<0.13,>=0.7.0 (from tensorflowjs==4.0.0)
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 16.1 MB/s eta 0:00:00
# Collecting wheel (from tensorflow-decision-forests==1.0.1)
#   Downloading wheel-0.43.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 9.9 MB/s eta 0:00:00
# Collecting wurlitzer (from tensorflow-decision-forests==1.0.1)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting charset-normalizer<4,>=2 (from requests->torchvision==0.12.0)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 21.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->torchvision==0.12.0)
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.4 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests->torchvision==0.12.0)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 17.2 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->torchvision==0.12.0)
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 24.0 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib>=2.2->seaborn==0.11.0)
#   Downloading contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 39.5 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib>=2.2->seaborn==0.11.0)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.2->seaborn==0.11.0)
#   Downloading fonttools-4.50.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 107.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.2->seaborn==0.11.0)
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 94.8 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.2->seaborn==0.11.0)
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 13.5 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 kB 25.9 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 18.0 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 113.3 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 73.5 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 28.5 MB/s eta 0:00:00
# Collecting msgpack (from flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading msgpack-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 42.6 MB/s eta 0:00:00
# Collecting optax (from flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading optax-0.2.2-py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 32.3 MB/s eta 0:00:00
# Collecting orbax-checkpoint (from flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading orbax_checkpoint-0.5.7-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 kB 21.1 MB/s eta 0:00:00
# Collecting tensorstore (from flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading tensorstore-0.1.56-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 86.2 MB/s eta 0:00:00
# Collecting rich>=11.1 (from flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 31.8 MB/s eta 0:00:00
# Collecting PyYAML>=5.4.1 (from flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 59.8 MB/s eta 0:00:00
# Collecting ml-dtypes>=0.2.0 (from jax>=0.3.16->tensorflowjs==4.0.0)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 97.6 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 26.7 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting chex>=0.1.86 (from optax->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading chex-0.1.86-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 16.5 MB/s eta 0:00:00
# Collecting jaxlib>=0.1.37 (from optax->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading jaxlib-0.4.25-cp310-cp310-manylinux2014_x86_64.whl (79.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 MB 9.7 MB/s eta 0:00:00
# Collecting etils[epath,epy] (from orbax-checkpoint->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading etils-1.7.0-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 21.5 MB/s eta 0:00:00
# Collecting nest_asyncio (from orbax-checkpoint->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 14.4 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=11.1->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.9 MB/s eta 0:00:00
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 11.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 21.3 MB/s eta 0:00:00
# Collecting toolz>=0.9.0 (from chex>=0.1.86->optax->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 8.4 MB/s eta 0:00:00
# Collecting fsspec; extra == "epath" (from etils[epath,epy]->orbax-checkpoint->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 22.2 MB/s eta 0:00:00
# Collecting zipp; extra == "epath" (from etils[epath,epy]->orbax-checkpoint->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.3->tensorflowjs==4.0.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: numpy, scipy, typing-extensions, torch, charset-normalizer, idna, urllib3, certifi, requests, pillow, torchvision, six, python-dateutil, pytz, pandas, contourpy, cycler, fonttools, kiwisolver, packaging, pyparsing, matplotlib, seaborn, absl-py, wheel, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, keras-preprocessing, libclang, opt-einsum, protobuf, setuptools, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, markdown, tensorboard-data-server, tensorboard-plugin-wit, MarkupSafe, werkzeug, tensorboard, tensorflow-io-gcs-filesystem, tensorflow-estimator, termcolor, wrapt, tensorflow, ml-dtypes, jax, msgpack, jaxlib, toolz, chex, optax, fsspec, importlib_resources, zipp, etils, PyYAML, tensorstore, nest_asyncio, orbax-checkpoint, mdurl, markdown-it-py, pygments, rich, flax, wurlitzer, tensorflow-decision-forests, tensorflow-hub, tensorflowjs
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.7
#     Uninstalling urllib3-1.26.7:
#       Successfully uninstalled urllib3-1.26.7
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.0
#     Uninstalling requests-2.25.0:
#       Successfully uninstalled requests-2.25.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.3.2
#     Uninstalling Pillow-8.3.2:
#       Successfully uninstalled Pillow-8.3.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1+cu121
#     Uninstalling torchvision-0.17.1+cu121:
#       Successfully uninstalled torchvision-0.17.1+cu121
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.4
#     Uninstalling pytz-2023.4:
#       Successfully uninstalled pytz-2023.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.2.0
#     Uninstalling contourpy-1.2.0:
#       Successfully uninstalled contourpy-1.2.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.50.0
#     Uninstalling fonttools-4.50.0:
#       Successfully uninstalled fonttools-4.50.0
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.5
#     Uninstalling kiwisolver-1.4.5:
#       Successfully uninstalled kiwisolver-1.4.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.3
#     Uninstalling matplotlib-3.5.3:
#       Successfully uninstalled matplotlib-3.5.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
#       Successfully uninstalled seaborn-0.13.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.43.0
#     Uninstalling wheel-0.43.0:
#       Successfully uninstalled wheel-0.43.0
#   Attempting uninstall: astunparse
#     Found existing installation: astunparse 1.6.3
#     Uninstalling astunparse-1.6.3:
#       Successfully uninstalled astunparse-1.6.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 24.3.7
#     Uninstalling flatbuffers-24.3.7:
#       Successfully uninstalled flatbuffers-24.3.7
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: google-pasta
#     Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.62.1
#     Uninstalling grpcio-1.62.1:
#       Successfully uninstalled grpcio-1.62.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: libclang
#     Found existing installation: libclang 18.1.1
#     Uninstalling libclang-18.1.1:
#       Successfully uninstalled libclang-18.1.1
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 3.3.0
#     Uninstalling opt-einsum-3.3.0:
#       Successfully uninstalled opt-einsum-3.3.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.3
#     Uninstalling cachetools-5.3.3:
#       Successfully uninstalled cachetools-5.3.3
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.5.1
#     Uninstalling pyasn1-0.5.1:
#       Successfully uninstalled pyasn1-0.5.1
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.3.0
#     Uninstalling pyasn1-modules-0.3.0:
#       Successfully uninstalled pyasn1-modules-0.3.0
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.27.0
#     Uninstalling google-auth-2.27.0:
#       Successfully uninstalled google-auth-2.27.0
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.2
#     Uninstalling oauthlib-3.2.2:
#       Successfully uninstalled oauthlib-3.2.2
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.4.0
#     Uninstalling requests-oauthlib-1.4.0:
#       Successfully uninstalled requests-oauthlib-1.4.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.6
#     Uninstalling Markdown-3.6:
#       Successfully uninstalled Markdown-3.6
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.1
#     Uninstalling Werkzeug-3.0.1:
#       Successfully uninstalled Werkzeug-3.0.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.36.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.36.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.36.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.23
#     Uninstalling jax-0.4.23:
#       Successfully uninstalled jax-0.4.23
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.8
#     Uninstalling msgpack-1.0.8:
#       Successfully uninstalled msgpack-1.0.8
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.23+cuda12.cudnn89
#     Uninstalling jaxlib-0.4.23+cuda12.cudnn89:
#       Successfully uninstalled jaxlib-0.4.23+cuda12.cudnn89
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.12.1
#     Uninstalling toolz-0.12.1:
#       Successfully uninstalled toolz-0.12.1
#   Attempting uninstall: chex
#     Found existing installation: chex 0.1.86
#     Uninstalling chex-0.1.86:
#       Successfully uninstalled chex-0.1.86
#   Attempting uninstall: optax
#     Found existing installation: optax 0.2.1
#     Uninstalling optax-0.2.1:
#       Successfully uninstalled optax-0.2.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: importlib_resources
#     Found existing installation: importlib_resources 6.4.0
#     Uninstalling importlib_resources-6.4.0:
#       Successfully uninstalled importlib_resources-6.4.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.18.1
#     Uninstalling zipp-3.18.1:
#       Successfully uninstalled zipp-3.18.1
#   Attempting uninstall: etils
#     Found existing installation: etils 1.7.0
#     Uninstalling etils-1.7.0:
#       Successfully uninstalled etils-1.7.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: tensorstore
#     Found existing installation: tensorstore 0.1.45
#     Uninstalling tensorstore-0.1.45:
#       Successfully uninstalled tensorstore-0.1.45
#   Attempting uninstall: nest_asyncio
#     Found existing installation: nest-asyncio 1.5.6
#     Uninstalling nest-asyncio-1.5.6:
#       Successfully uninstalled nest-asyncio-1.5.6
#   Attempting uninstall: orbax-checkpoint
#     Found existing installation: orbax-checkpoint 0.4.4
#     Uninstalling orbax-checkpoint-0.4.4:
#       Successfully uninstalled orbax-checkpoint-0.4.4
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.16.1
#     Uninstalling Pygments-2.16.1:
#       Successfully uninstalled Pygments-2.16.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: flax
#     Found existing installation: flax 0.8.2
#     Uninstalling flax-0.8.2:
#       Successfully uninstalled flax-0.8.2
#   Attempting uninstall: tensorflow-hub
#     Found existing installation: tensorflow-hub 0.16.1
#     Uninstalling tensorflow-hub-0.16.1:
#       Successfully uninstalled tensorflow-hub-0.16.1
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# bigframes 1.0.0 requires pandas>=1.5.0, but you'll have pandas 1.3.4 which is incompatible.
# bigframes 1.0.0 requires sqlalchemy<3.0dev,>=1.4, but you'll have sqlalchemy 1.3.22 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you'll have numpy 1.21.6 which is incompatible.
# flax 0.8.2 requires numpy>=1.22, but you'll have numpy 1.21.6 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you'll have fsspec 2024.3.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.27.0, but you'll have google-auth 2.29.0 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you'll have pandas 1.3.4 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you'll have pillow 10.2.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you'll have sqlalchemy 1.3.22 which is incompatible.
# jax 0.4.25 requires numpy>=1.22, but you'll have numpy 1.21.6 which is incompatible.
# jaxlib 0.4.25 requires numpy>=1.22, but you'll have numpy 1.21.6 which is incompatible.
# mizani 0.9.3 requires pandas>=1.3.5, but you'll have pandas 1.3.4 which is incompatible.
# numba 0.58.1 requires numpy<1.27,>=1.22, but you'll have numpy 1.21.6 which is incompatible.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you'll have google-auth-oauthlib 0.4.6 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you'll have numpy 1.21.6 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you'll have pandas 1.3.4 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you'll have numpy 1.21.6 which is incompatible.
# tensorflow-datasets 4.9.4 requires protobuf>=3.20, but you'll have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires absl-py<2.0.0,>=0.9, but you'll have absl-py 2.1.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you'll have protobuf 3.19.6 which is incompatible.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you'll have tensorflow 2.10.0 which is incompatible.
# theos-ai 0.0.36 requires matplotlib==3.5.3, but you'll have matplotlib 3.8.3 which is incompatible.
# theos-ai 0.0.36 requires nest-asyncio==1.5.6, but you'll have nest-asyncio 1.6.0 which is incompatible.
# theos-ai 0.0.36 requires Pillow==8.3.2, but you'll have pillow 10.2.0 which is incompatible.
# theos-ai 0.0.36 requires requests==2.25.0, but you'll have requests 2.31.0 which is incompatible.
# theos-ai 0.0.36 requires urllib3==1.26.7, but you'll have urllib3 2.2.1 which is incompatible.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you'll have torch 1.11.0 which is incompatible.
# torchdata 0.7.1 requires torch>=2, but you'll have torch 1.11.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you'll have torch 1.11.0 which is incompatible.
# tweepy 4.14.0 requires requests-oauthlib<2,>=1.2.0, but you'll have requests-oauthlib 2.0.0 which is incompatible.
# xarray 2023.7.0 requires pandas>=1.4, but you'll have pandas 1.3.4 which is incompatible.
# xarray-einstats 0.7.0 requires numpy>=1.22, but you'll have numpy 1.21.6 which is incompatible.
# tensorflowjs 4.0.0 requires packaging~=20.9, but you'll have packaging 24.0 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 PyYAML-6.0.1 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 chex-0.1.86 contourpy-1.2.0 cycler-0.12.1 etils-1.7.0 flatbuffers-24.3.25 flax-0.8.2 fonttools-4.50.0 fsspec-2024.3.1 gast-0.4.0 google-auth-2.29.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.62.1 h5py-3.10.0 idna-3.6 importlib_resources-6.4.0 jax-0.4.25 jaxlib-0.4.25 keras-2.10.0 keras-preprocessing-1.1.2 kiwisolver-1.4.5 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 matplotlib-3.8.3 mdurl-0.1.2 ml-dtypes-0.3.2 msgpack-1.0.8 nest_asyncio-1.6.0 numpy-1.21.6 oauthlib-3.2.2 opt-einsum-3.3.0 optax-0.2.2 orbax-checkpoint-0.5.7 packaging-24.0 pandas-1.3.4 pillow-10.2.0 protobuf-3.19.6 pyasn1-0.6.0 pyasn1-modules-0.4.0 pygments-2.17.2 pyparsing-3.1.2 python-dateutil-2.9.0.post0 pytz-2024.1 requests-2.31.0 requests-oauthlib-2.0.0 rich-13.7.1 rsa-4.9 scipy-1.11.1 seaborn-0.11.0 setuptools-69.2.0 six-1.16.0 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-decision-forests-1.0.1 tensorflow-estimator-2.10.0 tensorflow-hub-0.12.0 tensorflow-io-gcs-filesystem-0.36.0 tensorflowjs-4.0.0 tensorstore-0.1.56 termcolor-2.4.0 toolz-0.12.1 torch-1.11.0 torchvision-0.12.0 typing-extensions-4.10.0 urllib3-2.2.1 werkzeug-3.0.1 wheel-0.43.0 wrapt-1.16.0 wurlitzer-3.0.3 zipp-3.18.1
#
# [theos] done

# %% [markdown]
# ## 4. Restart the colab runtime
#
# Click the restart runtime option on the top menu.
#
# <img src="https://drive.google.com/uc?id=127ow4FbCF8cfBVfC-bWdhsv4l0-Usb2m" width="650px"/>

# %% [markdown]
# ## 5. Log in to your account

# %%
# !theos login
# Out:
#  Theos CLI
#
# [*] username: emma
# [*] password:
#
# [theos] login succeeded

# %% [markdown]
# # 6. Connect colab to your theos project
# Copy your theos project key and paste it next to **--project-key**
#
# (If the execution is not working well at any time, just stop this cell and run it again)

# %%
# !theos connect --project-key 3409ed26-629b-47dd-8d0e-8bcea244db21
# Out:
# [2024-03-27 21:52:25] [theos] machine with UUID db391724-4ba1-4ed9-9c61-541d72dfe21d registered successfully
# [2024-03-27 21:52:25] [theos] connecting machine...
# [2024-03-27 21:52:25] [theos] connected
# [2024-03-27 21:53:08] [theos] downloading yolov7 code:
#
# 100% 272k/272k [00:00<00:00, 1.62MB/s]
#
# [2024-03-27 21:53:09] [theos] extracting yolov7 code...
# [2024-03-27 21:53:09] [theos] creating license-plate dataset manifest:
#
# 100% 100.0/100 [00:15<00:00,  6.45it/s]
#
# [2024-03-27 21:53:25] [theos] downloading license-plate dataset manifest:
#
# 100% 406k/406k [00:00<00:00, 1.77MB/s]
#
# [2024-03-27 21:53:25] [theos] pulling license-plate dataset:
#
# 100% 669/669 [00:52<00:00, 12.79it/s]
#
# [2024-03-27 21:54:18] [theos] license-plate dataset pulled successfully in 52.0 seconds:
#
# 669 new
# 0 deleted
# 0 modified
#
# [2024-03-27 21:54:19] [theos] copying license-plate dataset train images to yolo_darknet folder...
# [2024-03-27 21:54:19] [theos] translating license-plate dataset train labels:
#
# 100% 311/311 [00:00<00:00, 6917.51it/s]
#
# [2024-03-27 21:54:19] [theos] copying license-plate dataset test images to yolo_darknet folder...
# [2024-03-27 21:54:19] [theos] translating license-plate dataset test labels:
#
# 100% 43/43 [00:00<00:00, 7785.34it/s]
#
# [2024-03-27 21:54:19] [theos] copying license-plate dataset valid images to yolo_darknet folder...
# [2024-03-27 21:54:19] [theos] translating license-plate dataset valid labels:
#
# 100% 89/89 [00:00<00:00, 6650.63it/s]
#
# [2024-03-27 21:54:19] [theos] dataset translated successfully
# [2024-03-27 21:54:20] [theos] importing yolov7 code...
# train: Scanning '/root/theos/system/computer-vision/object-detection/datasets/license-plate/formats/yolo_darknet/train/labels' images and labels... 160 found, 151 missing, 0 empty, 0 corrupted: 100% 311/311 [00:00<00:00, 3603.24it/s]
# train: New cache created: /root/theos/system/computer-vision/object-detection/datasets/license-plate/formats/yolo_darknet/train/labels.cache
# val: Scanning '/root/theos/system/computer-vision/object-detection/datasets/license-plate/formats/yolo_darknet/valid/labels' images and labels... 48 found, 41 missing, 0 empty, 0 corrupted: 100% 89/89 [00:00<00:00, 3117.35it/s]
# val: New cache created: /root/theos/system/computer-vision/object-detection/datasets/license-plate/formats/yolo_darknet/valid/labels.cache
#
# autoanchor: Analyzing anchors... anchors/target = 2.91, Best Possible Recall (BPR) = 1.0000
#
# Starting training for 300 epochs...
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    10/3000     1/300     7.82G      0.07183      0.02096      0.02633       0.1191           33          640: 100% 10/10 [00:22<00:00,  2.25s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:05<00:00,  3.00s/it]
#                  all          89         102    0.000424       0.563    0.000411    5.58e-05
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    20/3000     2/300     7.83G      0.06793       0.0182      0.02587        0.112           38          640: 100% 10/10 [00:09<00:00,  1.04it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:02<00:00,  1.34s/it]
#                  all          89         102     0.00066       0.461    0.000599    0.000111
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    30/3000     3/300     7.83G      0.06624      0.01505      0.02359       0.1049           43          640: 100% 10/10 [00:11<00:00,  1.12s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.10it/s]
#                  all          89         102    0.000734       0.432     0.00146    0.000423
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    40/3000     4/300     7.83G       0.0663      0.01319      0.02363       0.1031           45          640: 100% 10/10 [00:11<00:00,  1.11s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.18it/s]
#                  all          89         102       0.501      0.0873     0.00164    0.000426
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    50/3000     5/300     7.83G      0.06492      0.01219      0.02295       0.1001           35          640: 100% 10/10 [00:12<00:00,  1.23s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.39it/s]
#                  all          89         102       0.501      0.0873     0.00166    0.000328
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    60/3000     6/300     7.83G        0.066      0.01119      0.02303       0.1002           39          640: 100% 10/10 [00:11<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.08it/s]
#                  all          89         102       0.506      0.0159    0.000909    0.000161
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    70/3000     7/300     7.83G      0.06087      0.01078      0.02224      0.09389           43          640: 100% 10/10 [00:11<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.21it/s]
#                  all          89         102       0.501       0.127     0.00141    0.000236
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    80/3000     8/300     7.83G      0.06279      0.01002      0.02262      0.09544           28          640: 100% 10/10 [00:12<00:00,  1.27s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.91it/s]
#                  all          89         102       0.502       0.294     0.00482    0.000589
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#    90/3000     9/300     7.83G      0.05942     0.009653       0.0215      0.09057           39          640: 100% 10/10 [00:11<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.74it/s]
#                  all          89         102       0.503       0.183     0.00271    0.000361
#
#       Step     Epoch   GPU Mem     Box loss     Obj loss     Cls loss   Total loss      Targets     Img size
#